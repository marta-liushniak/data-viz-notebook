# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### QUALITATIVE DATA

# %%
listings = pd.read_csv('listings.csv')

# %%
listings
# Out:
#              id                                              name    host_id
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632  \
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
# to create a bar chart that will display the count of Airbnb listings in each neighbourhood group of NY city 
sns.countplot(x = 'neighbourhood_group', data = listings)
plt.show()

# %%
# to create a bar chart that will display the average price of Airbnb listings in each neighbourhood group of NY city 
sns.barplot(x = 'neighbourhood_group', y = 'price', data = listings)
plt.show()

# %%
# to remove the confidence intervals from the previous bar chart
sns.barplot(x = 'neighbourhood_group', y = 'price', data = listings, errorbar = ('ci', False))
plt.show()

# %% [markdown]
# ### QUANTITATIVE DATA

# %%
import numpy as np

# %%
listings
# Out:
#              id                                              name    host_id
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632  \
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
plt.hist(listings['price'])
plt.xlabel('price (in US $)')
plt.show()

# %%
plt.hist(listings['price'], bins = np.arange(0, 1100, 40))
plt.xlabel('price (in US $)')
plt.show()

# %%
plt.scatter(x = listings['price'], y = listings['number_of_reviews'])
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.show()

# %%
plt.scatter(x = listings['price'], y = listings['number_of_reviews'], s = 5)
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.xlim(0, 1100)
plt.show()
